# %% [markdown]
# # Reading and writing data across multiple formats

# %% [markdown]
# A practical introduction.

# %%
import pandas as pd

# %% [markdown]
# *import as pd* is a widely used convention
#
# in our data directory we have some files stored, lets import one!
