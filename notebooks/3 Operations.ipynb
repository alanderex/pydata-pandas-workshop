# %% [markdown]
# ![Königsweg Logo](../img/koenigsweg_150.png)

# %% [markdown]
# <span style="font-size: small;float: right;">&copy; 2015-2020 Alexander C.S. Hendorf, <a href="http://koenigsweg.com">Königsweg GmbH</a>, Mannheim </span>

# %% [markdown]
# ---

# %% [markdown]
# # Analytics with  Pandas and Jupyterlab

# %% [markdown]
# ---

# %% [markdown]
# # Operations

# %% [markdown]
# ---

# %%
import pandas as pd
import random
import numpy as np
import matplotlib
# %matplotlib inline

# %%
df = pd.read_json('../data/sampledf.json')
df.index = ["R{:02d}".format(i) for i in range(len(df))]
df.columns = ["C{:02d}".format(i) for i in range(len(df.columns))]
df
# Out:
#      C00  C01  C02  C03  C04  C05  C06  C07  C08  C09
# R00   79   19   21   99   35   59   44   25   75   58
# R01   25   39   89   66    9   41    6   69   63    3
# R02   37   64   31   69   61   97    5   11   76   57
# R03   74   61  100    6   58   80   95   50   15   51
# R04   79   60   83   85   16    5   16   69    5   20
# R05   45   26   73   73  100   60   21   19   95   12
# R06   12   29   18   98   62   68   92   29   74   96
# R07   36   32   22    4   66   25   63   51   59   14
# R08   55   53   89   13   84   87   74    3    2   64
# R09   46   74   36   54   21   12   68   33   80   25

# %% [markdown]
# ### Adding and deleting Series in a DataFrame

# %%
[random.randint(1, 100) for i in range(len(df))]
# Out:
# [3, 56, 55, 85, 44, 60, 89, 47, 6, 14]

# %%
df['C10'] = [random.randint(1, 100) for i in range(len(df))]
df
# Out:
#      C00  C01  C02  C03  C04  C05  C06  C07  C08  C09  C10
# R00   79   19   21   99   35   59   44   25   75   58   53
# R01   25   39   89   66    9   41    6   69   63    3   58
# R02   37   64   31   69   61   97    5   11   76   57   32
# R03   74   61  100    6   58   80   95   50   15   51   57
# R04   79   60   83   85   16    5   16   69    5   20   20
# R05   45   26   73   73  100   60   21   19   95   12   36
# R06   12   29   18   98   62   68   92   29   74   96    9
# R07   36   32   22    4   66   25   63   51   59   14   63
# R08   55   53   89   13   84   87   74    3    2   64   84
# R09   46   74   36   54   21   12   68   33   80   25    8

# %%
# caveat when adding a Series:
new_series = pd.Series(list([random.randint(1, 100) for i in range(len(df))]))
new_series
# Out:
# 0    82
# 1    80
# 2    93
# 3    55
# 4    60
# 5    79
# 6    71
# 7    56
# 8     4
# 9    39
# dtype: int64

# %%
df['C10'] = new_series
df
# Out:
#      C00  C01  C02  C03  C04  C05  C06  C07  C08  C09  C10
# R00   79   19   21   99   35   59   44   25   75   58  NaN
# R01   25   39   89   66    9   41    6   69   63    3  NaN
# R02   37   64   31   69   61   97    5   11   76   57  NaN
# R03   74   61  100    6   58   80   95   50   15   51  NaN
# R04   79   60   83   85   16    5   16   69    5   20  NaN
# R05   45   26   73   73  100   60   21   19   95   12  NaN
# R06   12   29   18   98   62   68   92   29   74   96  NaN
# R07   36   32   22    4   66   25   63   51   59   14  NaN
# R08   55   53   89   13   84   87   74    3    2   64  NaN
# R09   46   74   36   54   21   12   68   33   80   25  NaN

# %%
# adding a new Series: mind the index of the the DF
new_series.index = df.index
new_series
# Out:
# R00    82
# R01    80
# R02    93
# R03    55
# R04    60
# R05    79
# R06    71
# R07    56
# R08     4
# R09    39
# dtype: int64

# %%
df['C10'] = new_series
df
# Out:
#      C00  C01  C02  C03  C04  C05  C06  C07  C08  C09  C10
# R00   79   19   21   99   35   59   44   25   75   58   82
# R01   25   39   89   66    9   41    6   69   63    3   80
# R02   37   64   31   69   61   97    5   11   76   57   93
# R03   74   61  100    6   58   80   95   50   15   51   55
# R04   79   60   83   85   16    5   16   69    5   20   60
# R05   45   26   73   73  100   60   21   19   95   12   79
# R06   12   29   18   98   62   68   92   29   74   96   71
# R07   36   32   22    4   66   25   63   51   59   14   56
# R08   55   53   89   13   84   87   74    3    2   64    4
# R09   46   74   36   54   21   12   68   33   80   25   39

# %%
df['C11'] = new_series
df
# Out:
#      C00  C01  C02  C03  C04  C05  C06  C07  C08  C09  C10  C11
# R00   79   19   21   99   35   59   44   25   75   58   82   82
# R01   25   39   89   66    9   41    6   69   63    3   80   80
# R02   37   64   31   69   61   97    5   11   76   57   93   93
# R03   74   61  100    6   58   80   95   50   15   51   55   55
# R04   79   60   83   85   16    5   16   69    5   20   60   60
# R05   45   26   73   73  100   60   21   19   95   12   79   79
# R06   12   29   18   98   62   68   92   29   74   96   71   71
# R07   36   32   22    4   66   25   63   51   59   14   56   56
# R08   55   53   89   13   84   87   74    3    2   64    4    4
# R09   46   74   36   54   21   12   68   33   80   25   39   39

# %%
del df['C11']
df
# Out:
#      C00  C01  C02  C03  C04  C05  C06  C07  C08  C09  C10
# R00   79   19   21   99   35   59   44   25   75   58   82
# R01   25   39   89   66    9   41    6   69   63    3   80
# R02   37   64   31   69   61   97    5   11   76   57   93
# R03   74   61  100    6   58   80   95   50   15   51   55
# R04   79   60   83   85   16    5   16   69    5   20   60
# R05   45   26   73   73  100   60   21   19   95   12   79
# R06   12   29   18   98   62   68   92   29   74   96   71
# R07   36   32   22    4   66   25   63   51   59   14   56
# R08   55   53   89   13   84   87   74    3    2   64    4
# R09   46   74   36   54   21   12   68   33   80   25   39

# %%
del df['C12']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda/envs/pydata-pandas-workshop/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C12'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-bbf8fe38b188> in <module>
# ----> 1 del df['C12']
#
# ~/anaconda/envs/pydata-pandas-workshop/lib/python3.7/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    3313             # there was no match, this call should raise the appropriate
#    3314             # exception:
# -> 3315             self._data.delete(key)
#    3316
#    3317         # delete from the caches
#
# ~/anaconda/envs/pydata-pandas-workshop/lib/python3.7/site-packages/pandas/core/internals/managers.py in delete(self, item)
#     983         Delete selected item (items if non-unique) in-place.
#     984         """
# --> 985         indexer = self.items.get_loc(item)
#     986
#     987         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~/anaconda/envs/pydata-pandas-workshop/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C12'

# %%
# avoid KeyErrors if unsure Series exists
df.drop(['C12'], errors='ignore')
# Out:
#      C00  C01  C02  C03  C04  C05  C06  C07  C08  C09  C10
# R00   79   19   21   99   35   59   44   25   75   58   82
# R01   25   39   89   66    9   41    6   69   63    3   80
# R02   37   64   31   69   61   97    5   11   76   57   93
# R03   74   61  100    6   58   80   95   50   15   51   55
# R04   79   60   83   85   16    5   16   69    5   20   60
# R05   45   26   73   73  100   60   21   19   95   12   79
# R06   12   29   18   98   62   68   92   29   74   96   71
# R07   36   32   22    4   66   25   63   51   59   14   56
# R08   55   53   89   13   84   87   74    3    2   64    4
# R09   46   74   36   54   21   12   68   33   80   25   39

# %%
# getting a subset is simpler than delting many columns
dfs = df.loc[:, ['C03', 'C05']]
dfs
# Out:
#      C03  C05
# R00   99   59
# R01   66   41
# R02   69   97
# R03    6   80
# R04   85    5
# R05   73   60
# R06   98   68
# R07    4   25
# R08   13   87
# R09   54   12

# %% [markdown]
# ### Mangle your data

# %% [markdown]
# **recall: NumPy Broadcasting**

# %%
a = np.random.rand(3,1)
a
# Out:
# array([[0.2230008 ],
#        [0.02635492],
#        [0.11253093]])

# %%
b = np.random.rand(3,1)
b
# Out:
# array([[0.45444605],
#        [0.14779185],
#        [0.95504478]])

# %%
a + b
# Out:
# array([[0.67744685],
#        [0.17414677],
#        [1.06757572]])

# %%
a - b
# Out:
# array([[-0.23144525],
#        [-0.12143693],
#        [-0.84251385]])

# %%
a * b
# Out:
# array([[0.10134183],
#        [0.00389504],
#        [0.10747208]])

# %%
a / b
# Out:
# array([[0.49070908],
#        [0.17832458],
#        [0.11782791]])

# %%
a + 7
# Out:
# array([[7.2230008 ],
#        [7.02635492],
#        [7.11253093]])

# %%
b // 2
# Out:
# array([[0.],
#        [0.],
#        [0.]])

# %%
a % 2 == 0
# Out:
# array([[False],
#        [False],
#        [False]])

# %%
a * [4, 5]
# Out:
# array([[0.89200322, 1.11500402],
#        [0.10541968, 0.1317746 ],
#        [0.45012374, 0.56265467]])

# %% [markdown]
# ### Broadcasting in Pandas

# %%
sales_data = pd.read_json('../data/blooth_sales_data.json',
                              convert_dates=['birthday', 'orderdate']
                              )
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene 2016-10-02 08:21:20.544643
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units
# 0          Star Wars      11.81     27
# 1        PlayStation     284.71      1
# 2             banana      10.00     49
# 3    Thriller record      16.77     48
# 4  Harry Potter book       5.65      4

# %%
sales_data['turnover'] = sales_data['unitprice'] * sales_data['units']
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene 2016-10-02 08:21:20.544643
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover
# 0          Star Wars      11.81     27    318.87
# 1        PlayStation     284.71      1    284.71
# 2             banana      10.00     49    490.00
# 3    Thriller record      16.77     48    804.96
# 4  Harry Potter book       5.65      4     22.60

# %%
sales_data['turnover'].mean()
# Out:
# 59915.64764605545

# %%
sales_data.mean()
# Out:
# unitprice     2329.681343
# units           25.808102
# turnover     59915.647646
# dtype: float64

# %%
sales_data['turnover'].sum()
# Out:
# 140502193.73000002

# %%
sales_data['turnover'].median()
# Out:
# 532.14

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2345 entries, 0 to 2344
# Data columns (total 8 columns):
# birthday     2345 non-null datetime64[ns]
# customer     2345 non-null object
# name         2345 non-null object
# orderdate    2345 non-null datetime64[ns]
# product      2345 non-null object
# unitprice    2345 non-null float64
# units        2345 non-null int64
# turnover     2345 non-null float64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(3)
# memory usage: 146.6+ KB

# %% [markdown]
# ### Excercise

# %% [markdown]
# Calculate the mean without using .mean

# %%
# your code here

# %%
# %load ../solutions/301.py
sales_data['turnover'].sum() / len(sales_data)
# Out:
# 59915.64764605545

# %%
sales_data.describe()
# Out:
#           unitprice        units      turnover
# count   2345.000000  2345.000000  2.345000e+03
# mean    2329.681343    25.808102  5.991565e+04
# std     6582.327614    14.474110  1.969636e+05
# min        5.010000     1.000000  5.080000e+00
# 25%       10.660000    13.000000  2.601000e+02
# 50%       17.850000    26.000000  5.321400e+02
# 75%      489.940000    39.000000  1.016450e+04
# max    24895.630000    50.000000  1.222270e+06

# %% [markdown]
# Find the oldest customer (bithday)

# %%
# your code here
sales_data[sales_data['birthday'] == sales_data['birthday'].min()]
# Out:
#        birthday                               customer  name  \
# 79   1952-02-07  Galaxy Omega Consulting International  Lesa
# 133  1952-02-07  Galaxy Omega Consulting International  Lesa
# 533  1952-02-07  Galaxy Omega Consulting International  Lesa
# 869  1952-02-07  Galaxy Omega Consulting International  Lesa
# 1162 1952-02-07  Galaxy Omega Consulting International  Lesa
# 1240 1952-02-07  Galaxy Omega Consulting International  Lesa
# 1495 1952-02-07  Galaxy Omega Consulting International  Lesa
# 1673 1952-02-07  Galaxy Omega Consulting International  Lesa
# 2304 1952-02-07  Galaxy Omega Consulting International  Lesa
#
#                       orderdate            product  unitprice  units  \
# 79   2016-10-08 08:21:20.546301            Lipitor      10.61     41
# 133  2016-10-04 08:21:20.547337  Harry Potter book      17.34     13
# 533  2016-10-15 08:21:20.555514            Lipitor      10.17     26
# 869  2016-09-30 08:21:20.562135    Thriller record      12.52     32
# 1162 2016-10-13 08:21:20.567897            Lipitor      10.33      5
# 1240 2016-10-05 08:21:20.569503            Lipitor      11.21     45
# 1495 2016-09-27 08:21:20.575694    Thriller record      15.86     14
# 1673 2016-09-27 08:21:20.579335            Corolla   22227.77     25
# 2304 2016-10-09 08:21:20.592369          Star Wars       8.24     28
#
#        turnover
# 79       435.01
# 133      225.42
# 533      264.42
# 869      400.64
# 1162      51.65
# 1240     504.45
# 1495     222.04
# 1673  555694.25
# 2304     230.72

# %%
sales_data[sales_data['birthday'] == sales_data['birthday'].min()]['name'].unique()
# Out:
# array(['Lesa'], dtype=object)

# %%
sales_data[sales_data['birthday'] == sales_data['birthday'].min()]['name'].nunique()
# Out:
# 1

# %%
# %load ../solutions/302.py

# %% [markdown]
# ### Method with **`.map(), .apply() .applymap()`**

# %%
def get_year(datetime_):
    return datetime_.year

# %%
sales_data['orderdate'][0]
# Out:
# Timestamp('2016-10-06 08:21:20.544568')

# %%
# map for Series
sales_data['year'] = sales_data['orderdate'].map(get_year)
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene 2016-10-02 08:21:20.544643
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year
# 0          Star Wars      11.81     27    318.87  2016
# 1        PlayStation     284.71      1    284.71  2016
# 2             banana      10.00     49    490.00  2016
# 3    Thriller record      16.77     48    804.96  2016
# 4  Harry Potter book       5.65      4     22.60  2016

# %%
# map for Series
sales_data['year'] = sales_data['orderdate'].map(lambda x: x.year)
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene 2016-10-02 08:21:20.544643
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year
# 0          Star Wars      11.81     27    318.87  2016
# 1        PlayStation     284.71      1    284.71  2016
# 2             banana      10.00     49    490.00  2016
# 3    Thriller record      16.77     48    804.96  2016
# 4  Harry Potter book       5.65      4     22.60  2016

# %%
# map for Series
sales_data['month'] = sales_data['orderdate'].map(lambda x: x.month)
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene 2016-10-02 08:21:20.544643
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month
# 0          Star Wars      11.81     27    318.87  2016     10
# 1        PlayStation     284.71      1    284.71  2016      9
# 2             banana      10.00     49    490.00  2016     10
# 3    Thriller record      16.77     48    804.96  2016     10
# 4  Harry Potter book       5.65      4     22.60  2016     10

# %%
# combine multiple columns
sales_data['year-month'] = sales_data['year'].map(
    str) + sales_data['month'].map(lambda x: "-{:02d}".format(x))

# %%
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene 2016-10-02 08:21:20.544643
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      11.81     27    318.87  2016     10    2016-10
# 1        PlayStation     284.71      1    284.71  2016      9    2016-09
# 2             banana      10.00     49    490.00  2016     10    2016-10
# 3    Thriller record      16.77     48    804.96  2016     10    2016-10
# 4  Harry Potter book       5.65      4     22.60  2016     10    2016-10

# %%
sales_data[['unitprice', 'units']]
# Out:
#       unitprice  units
# 0         11.81     27
# 1        284.71      1
# 2         10.00     49
# 3         16.77     48
# 4          5.65      4
# 5       1037.42     15
# 6         15.97     48
# 7         18.17     18
# 8        282.94     39
# 9          9.85     49
# 10        16.05     34
# 11        10.00     50
# 12     21513.13     50
# 13        10.00     20
# 14        11.30     28
# 15        18.94     43
# 16        16.00      9
# 17        26.80     20
# 18        17.08     48
# 19        10.06     38
# 20        16.29     27
# 21        22.69     36
# 22        14.41     42
# 23     24108.96      3
# 24        17.93     44
# 25        16.44     47
# 26       234.91      7
# 27        16.55     17
# 28         8.08     33
# 29        11.06     45
# ...         ...    ...
# 2315       6.13     38
# 2316     580.45     26
# 2317     551.96      1
# 2318      18.96     16
# 2319      18.24     42
# 2320     291.09     14
# 2321     212.57     26
# 2322   24285.01     24
# 2323     279.58     35
# 2324      18.78     47
# 2325      10.52     50
# 2326   20753.82     16
# 2327     280.21      5
# 2328   24620.37      9
# 2329     274.41     34
# 2330      15.70     37
# 2331      15.61     15
# 2332     691.46     20
# 2333     540.11      4
# 2334     643.12     20
# 2335       7.11      6
# 2336      10.13     11
# 2337   22111.53     31
# 2338     619.10     27
# 2339      10.98      2
# 2340      16.56     42
# 2341      10.39     36
# 2342      16.75     27
# 2343     897.07      9
# 2344      11.85     16
#
# [2345 rows x 2 columns]

# %%
# applymap for df
sales_data[['unitprice', 'units']].applymap(lambda x: np.round(4 * x, 2)).head(5)
# Out:
#    unitprice  units
# 0      47.24    108
# 1    1138.84      4
# 2      40.00    196
# 3      67.08    192
# 4      22.60     16

# %%
sales_data[['unitprice', 'units']].apply(lambda x: np.round(4 * x, 2)).head(5)
# Out:
#    unitprice  units
# 0      47.24    108
# 1    1138.84      4
# 2      40.00    196
# 3      67.08    192
# 4      22.60     16

# %% [markdown]
# #####  Differences of **`.map(), .apply() .applymap()`**

# %% [markdown]
#  * **`.map()`**
#  >iterate over each element of a DataFrame

# %%
sales_data['unitprice'].map(int)[:5]
# Out:
# 0     11
# 1    284
# 2     10
# 3     16
# 4      5
# Name: unitprice, dtype: int64

# %% [markdown]
#  * **`.apply()`**
#  > apply a fucntion on an axis of the DataFrame.

# %% [markdown]
# e.g. sum up two cells (hier: unitprice + units)

# %%
sales_data[['unitprice', 'units']].apply(sum, axis=1)[:5]# default axis=0
# Out:
# 0     38.81
# 1    285.71
# 2     59.00
# 3     64.77
# 4      9.65
# dtype: float64

# %% [markdown]
#  * **`.applymap()`**
#  > apply a function on each element of the DataFrame

# %%
sales_data[['unitprice', 'units']].applymap(int)[:5]
# Out:
#    unitprice  units
# 0         11     27
# 1        284      1
# 2         10     49
# 3         16     48
# 4          5      4

# %% [markdown]
# #### Remember: a copy of the DF is returned. The DF is not altered.

# %%
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene 2016-10-02 08:21:20.544643
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      11.81     27    318.87  2016     10    2016-10
# 1        PlayStation     284.71      1    284.71  2016      9    2016-09
# 2             banana      10.00     49    490.00  2016     10    2016-10
# 3    Thriller record      16.77     48    804.96  2016     10    2016-10
# 4  Harry Potter book       5.65      4     22.60  2016     10    2016-10

# %%
sales_data['unitprice'] = sales_data['unitprice'].map(lambda x: x * 2)

# %%
sales_data.describe()
# Out:
#           unitprice        units      turnover    year        month
# count   2345.000000  2345.000000  2.345000e+03  2345.0  2345.000000
# mean    4659.362687    25.808102  5.991565e+04  2016.0     9.812793
# std    13164.655228    14.474110  1.969636e+05     0.0     0.390161
# min       10.020000     1.000000  5.080000e+00  2016.0     9.000000
# 25%       21.320000    13.000000  2.601000e+02  2016.0    10.000000
# 50%       35.700000    26.000000  5.321400e+02  2016.0    10.000000
# 75%      979.880000    39.000000  1.016450e+04  2016.0    10.000000
# max    49791.260000    50.000000  1.222270e+06  2016.0    10.000000

# %%
sales_data['birthday'].describe()
# Out:
# count                    2345
# unique                    296
# top       1998-04-20 00:00:00
# freq                       19
# first     1952-02-07 00:00:00
# last      1999-05-01 00:00:00
# Name: birthday, dtype: object

# %%
sales_data['turnover'] = sales_data['turnover'].astype(np.int)
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene 2016-10-02 08:21:20.544643
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      23.62     27       318  2016     10    2016-10
# 1        PlayStation     569.42      1       284  2016      9    2016-09
# 2             banana      20.00     49       490  2016     10    2016-10
# 3    Thriller record      33.54     48       804  2016     10    2016-10
# 4  Harry Potter book      11.30      4        22  2016     10    2016-10

# %%
# sneak in NaN
sales_data.set_value(1, 'unitprice', np.NaN)
sales_data.set_value(4, 'unitprice', np.NaN)
sales_data.set_value(3, 'orderdate', np.NaN)
sales_data.head(5)
# Out:
# /Users/hendorf/anaconda/envs/pydata-pandas-workshop/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /Users/hendorf/anaconda/envs/pydata-pandas-workshop/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hendorf/anaconda/envs/pydata-pandas-workshop/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene                        NaT
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      23.62     27       318  2016     10    2016-10
# 1        PlayStation        NaN      1       284  2016      9    2016-09
# 2             banana      20.00     49       490  2016     10    2016-10
# 3    Thriller record      33.54     48       804  2016     10    2016-10
# 4  Harry Potter book        NaN      4        22  2016     10    2016-10

# %%
# sneak in NaN
sales_data.at[1, 'unitprice'] = np.NaN
sales_data.at[4, 'unitprice'] = np.NaN
sales_data.at[3, 'orderdate'] = np.NaN
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene                        NaT
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      23.62     27       318  2016     10    2016-10
# 1        PlayStation        NaN      1       284  2016      9    2016-09
# 2             banana      20.00     49       490  2016     10    2016-10
# 3    Thriller record      33.54     48       804  2016     10    2016-10
# 4  Harry Potter book        NaN      4        22  2016     10    2016-10

# %%
sales_data[sales_data['unitprice'].isnull()]
# Out:
#     birthday              customer    name                  orderdate  \
# 1 1986-02-05  Bell Telecom Limited   Queen 2016-09-30 08:21:20.544599
# 4 1984-12-14          Frontier Inc  Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 1        PlayStation        NaN      1       284  2016      9    2016-09
# 4  Harry Potter book        NaN      4        22  2016     10    2016-10

# %%
sales_data.dropna().head(5)
# Out:
#     birthday             customer      name                  orderdate  \
# 0 1974-01-07  Frontier Industries   Ernesto 2016-10-06 08:21:20.544568
# 2 1982-07-06          Software Co      Reid 2016-10-05 08:21:20.544622
# 5 1987-08-06   Internet Alpha Inc     Verna 2016-10-03 08:21:20.544687
# 6 1962-10-10    Galaxy Industries    Stacia 2016-10-08 08:21:20.544707
# 7 1979-03-02         Alpha Agency  Migdalia 2016-09-29 08:21:20.544726
#
#         product  unitprice  units  turnover  year  month year-month
# 0     Star Wars      23.62     27       318  2016     10    2016-10
# 2        banana      20.00     49       490  2016     10    2016-10
# 5          iPad    2074.84     15     15561  2016     10    2016-10
# 6  Rubik’s Cube      31.94     48       766  2016     10    2016-10
# 7  Rubik’s Cube      36.34     18       327  2016      9    2016-09

# %%
sales_data.head(5)
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene                        NaT
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      23.62     27       318  2016     10    2016-10
# 1        PlayStation        NaN      1       284  2016      9    2016-09
# 2             banana      20.00     49       490  2016     10    2016-10
# 3    Thriller record      33.54     48       804  2016     10    2016-10
# 4  Harry Potter book        NaN      4        22  2016     10    2016-10

# %%
sales_data.fillna(99.99).head(5)
# Out:
#     birthday               customer     name                   orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto  2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen  2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid  2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene                       99.99
# 4 1984-12-14           Frontier Inc   Nikita  2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      23.62     27       318  2016     10    2016-10
# 1        PlayStation      99.99      1       284  2016      9    2016-09
# 2             banana      20.00     49       490  2016     10    2016-10
# 3    Thriller record      33.54     48       804  2016     10    2016-10
# 4  Harry Potter book      99.99      4        22  2016     10    2016-10

# %%
sales_data.head()
# Out:
#     birthday               customer     name                  orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto 2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen 2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid 2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene                        NaT
# 4 1984-12-14           Frontier Inc   Nikita 2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      23.62     27       318  2016     10    2016-10
# 1        PlayStation        NaN      1       284  2016      9    2016-09
# 2             banana      20.00     49       490  2016     10    2016-10
# 3    Thriller record      33.54     48       804  2016     10    2016-10
# 4  Harry Potter book        NaN      4        22  2016     10    2016-10

# %%
# sales_data = sales_data.fillna(99.99)

# %%
sales_data.fillna(99.99, inplace=True)
sales_data.head(5)
# Out:
#     birthday               customer     name                   orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto  2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen  2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid  2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene                       99.99
# 4 1984-12-14           Frontier Inc   Nikita  2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      23.62     27       318  2016     10    2016-10
# 1        PlayStation      99.99      1       284  2016      9    2016-09
# 2             banana      20.00     49       490  2016     10    2016-10
# 3    Thriller record      33.54     48       804  2016     10    2016-10
# 4  Harry Potter book      99.99      4        22  2016     10    2016-10

# %%
sales_data = sales_data.fillna(99.99)
sales_data.head(5)
# Out:
#     birthday               customer     name                   orderdate  \
# 0 1974-01-07    Frontier Industries  Ernesto  2016-10-06 08:21:20.544568
# 1 1986-02-05   Bell Telecom Limited    Queen  2016-09-30 08:21:20.544599
# 2 1982-07-06            Software Co     Reid  2016-10-05 08:21:20.544622
# 3 1971-04-12  Data Design Galaxy Co   Arlene                       99.99
# 4 1984-12-14           Frontier Inc   Nikita  2016-10-16 08:21:20.544666
#
#              product  unitprice  units  turnover  year  month year-month
# 0          Star Wars      23.62     27       318  2016     10    2016-10
# 1        PlayStation      99.99      1       284  2016      9    2016-09
# 2             banana      20.00     49       490  2016     10    2016-10
# 3    Thriller record      33.54     48       804  2016     10    2016-10
# 4  Harry Potter book      99.99      4        22  2016     10    2016-10
